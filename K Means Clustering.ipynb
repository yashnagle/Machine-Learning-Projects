# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=101)#Creating artificial data

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans()

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.30355561,  5.09608015],
#        [-9.18960987, -8.53584776],
#        [-5.3764121 ,  7.42995629],
#        [-0.0950357 ,  0.97777524],
#        [ 3.92954455,  8.25960182],
#        [-9.67203831, -5.13061964],
#        [ 5.11653306,  4.48455218],
#        [-2.41575022,  8.84918197]])

# %%
kmeans.labels_
# Out:
# array([2, 6, 0, 4, 4, 5, 4, 3, 4, 3, 2, 3, 4, 0, 2, 3, 6, 3, 5, 7, 5, 3,
#        0, 1, 2, 1, 1, 3, 4, 6, 7, 1, 6, 3, 3, 2, 5, 5, 1, 3, 5, 7, 7, 7,
#        3, 0, 2, 0, 1, 0, 3, 2, 6, 3, 5, 0, 0, 3, 2, 4, 1, 0, 5, 7, 4, 3,
#        5, 6, 4, 5, 4, 0, 5, 0, 5, 6, 4, 3, 2, 3, 0, 5, 4, 5, 3, 3, 3, 2,
#        0, 5, 1, 5, 5, 0, 0, 1, 4, 2, 5, 6, 0, 5, 0, 3, 0, 0, 5, 4, 1, 5,
#        6, 7, 2, 4, 1, 4, 7, 2, 0, 7, 0, 2, 3, 2, 3, 6, 2, 3, 1, 7, 2, 7,
#        3, 1, 5, 2, 6, 2, 4, 3, 1, 6, 5, 7, 7, 0, 0, 1, 2, 2, 7, 7, 3, 6,
#        3, 2, 0, 4, 4, 3, 4, 3, 0, 2, 5, 2, 3, 4, 7, 6, 4, 3, 2, 0, 0, 2,
#        4, 0, 1, 0, 7, 1, 1, 7, 5, 1, 5, 1, 1, 3, 5, 4, 4, 2, 5, 0, 4, 4,
#        5, 3])

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

# %%
fig , (ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# # SSE
